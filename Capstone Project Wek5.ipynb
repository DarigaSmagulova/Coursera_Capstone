# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# ### Exploring NY dataset

# %%
CLIENT_ID = 
CLIENT_SECRET = 
VERSION = '20180605' 
LIMIT=100
search_query='coffee'

# %%
with open('nyu_2451_34572-geojson.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
loc = geolocator.geocode(address)
lat = loc.latitude
long = loc.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(lat, long))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[lat, long], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Explore each Borough's neighborhood and their coffee shops

# %% [markdown]
# ##### Let's create a function to repeat the same process to all the neighborhoods in all boroughs

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# function to get neccessary venues near location
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET,  
        lat, 
        lng, 
        VERSION,
        search_query,
        radius, 
        LIMIT)

        # make the GET request
    results = requests.get(url).json()["response"]['venues']
        
    dataframe = json_normalize(results)
    # keep only columns that include venue name, latitude and longitude
    filtered_columns = ['name', 'categories'] +['location.lat','location.lng']+['id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
    dataframe_filtered['Neighborhood']=name 
    dataframe_filtered['Neighborhood Latitude']=lat
    dataframe_filtered ['Neighborhood Longitude']=lng
    
    dataframe_filtered=dataframe_filtered.rename(columns={"name": "Venue", "categories": "Venue category",'location.lat': 'Venue Latitide', 'location.lng':'Venue Longitude' })              
    
    return(dataframe_filtered)

# %%
# Function to get venues rating
def get_rating(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

    result = requests.get(url).json()
    try:
        return result['response']['venue']['rating']
    except:
        return(0)

# %% [markdown]
# ### 1. Manhattan

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Applying function of getting venues with coffee to Manhattan
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude'])
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
ids=manhattan_venues['id'].tolist()
score=[]
for vid in ids:
    score.append(get_rating(vid))
manhattan_venues['rating']=score

# %%
manhattan_venues.head()
# Out:
#                      Venue Venue category  Venue Latitide  Venue Longitude  \
# 0  Romeo and Juliet Coffee    Coffee Shop       40.760726       -73.997724
# 1     Oslo Coffee Roasters    Coffee Shop       40.760512       -73.998985
# 2          Clovelly Coffee    Coffee Shop       40.753292       -73.996745
# 3          R/GA Coffee Bar           Café       40.755948       -73.993659
# 4       Blue Bottle Coffee    Coffee Shop       40.753846       -74.002250
#
#                          id  Neighborhood  Neighborhood Latitude  \
# 0  526d9114498ec8efda93fcce  Hudson Yards              40.756658
# 1  5c683caaf96b2c00397a8609  Hudson Yards              40.756658
# 2  5d6165d5716af50008cde370  Hudson Yards              40.756658
# 3  4b9fe9eef964a520f84937e3  Hudson Yards              40.756658
# 4  5c8d246c492822003a5a5a6e  Hudson Yards              40.756658
#
#    Neighborhood Longitude  rating
# 0              -74.000111     7.5
# 1              -74.000111     8.3
# 2              -74.000111     7.7
# 3              -74.000111     0.0
# 4              -74.000111     7.4

# %%
manhattan_venues.groupby('Neighborhood').count()
# Out:
#               Venue  Venue category  Venue Latitide  Venue Longitude  id  \
# Neighborhood
# Hudson Yards     21              21              21               21  21
#
#               Neighborhood Latitude  Neighborhood Longitude  rating
# Neighborhood
# Hudson Yards                     21                      21      21

# %%
manhattan_venues.groupby('Venue category').count()
# Out:
#                            Venue  Venue Latitide  Venue Longitude  id  \
# Venue category
# Breakfast Spot                 2               2                2   2
# Café                           3               3                3   3
# Coffee Shop                   11              11               11  11
# Deli / Bodega                  1               1                1   1
# Food                           1               1                1   1
# Food Truck                     1               1                1   1
# Latin American Restaurant      1               1                1   1
# Restaurant                     1               1                1   1
#
#                            Neighborhood  Neighborhood Latitude  \
# Venue category
# Breakfast Spot                        2                      2
# Café                                  3                      3
# Coffee Shop                          11                     11
# Deli / Bodega                         1                      1
# Food                                  1                      1
# Food Truck                            1                      1
# Latin American Restaurant             1                      1
# Restaurant                            1                      1
#
#                            Neighborhood Longitude  rating
# Venue category
# Breakfast Spot                                  2       2
# Café                                            3       3
# Coffee Shop                                    11      11
# Deli / Bodega                                   1       1
# Food                                            1       1
# Food Truck                                      1       1
# Latin American Restaurant                       1       1
# Restaurant                                      1       1

# %% [markdown]
# ### 2. Bronx

# %%
bronx_data = neighborhoods[neighborhoods['Borough'] == 'Bronx'].reset_index(drop=True)
bronx_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
address = 'Bronx, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of bronx are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of bronx are 40.8466508, -73.8785937.

# %%
# create map of bronx using latitude and longitude values
map_bronx = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(bronx_data['Latitude'], bronx_data['Longitude'], bronx_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_bronx)  
    
map_bronx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query='coffee'
bronx_coffee = getNearbyVenues(names=bronx_data['Neighborhood'],
                                   latitudes=bronx_data['Latitude'],
                                   longitudes=bronx_data['Longitude'],radius=1000)
# Out:
# Wakefield
# Co-op City
# Eastchester
# Fieldston
# Riverdale
# Kingsbridge
# Woodlawn
# Norwood
# Williamsbridge
# Baychester
# Pelham Parkway
# City Island
# Bedford Park
# University Heights
# Morris Heights
# Fordham
# East Tremont
# West Farms
# High  Bridge
# Melrose
# Mott Haven
# Port Morris
# Longwood
# Hunts Point
# Morrisania
# Soundview
# Clason Point
# Throgs Neck
# Country Club
# Parkchester
# Westchester Square
# Van Nest
# Morris Park
# Belmont
# Spuyten Duyvil
# North Riverdale
# Pelham Bay
# Schuylerville
# Edgewater Park
# Castle Hill
# Olinville
# Pelham Gardens
# Concourse
# Unionport
# Edenwald
# Claremont Village
# Concourse Village
# Mount Eden
# Mount Hope
# Bronxdale
# Allerton
# Kingsbridge Heights
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
ids=bronx_coffee['id'].tolist()
score=[]
for vid in ids:
    score.append(get_rating(vid))
bronx_coffee['rating']=score

# %%
bronx_coffee.head()
# Out:
#                             Venue  Venue category  Venue Latitide  \
# 0    National Restaurant & Coffee           Diner       40.873007
# 1             Perista Coffee Shop     Coffee Shop       40.868314
# 2  Kingsbridge Coffee Shop & Deli     Coffee Shop       40.867210
# 3                     Coffee Cart  Breakfast Spot       40.874555
# 4       Coffee Cart on Fordham Rd      Food Truck       40.861292
#
#    Venue Longitude                        id         Neighborhood  \
# 0       -73.889082  4b78a508f964a520b4db2ee3  Kingsbridge Heights
# 1       -73.901298  5156f35be4b0dc046e1af723  Kingsbridge Heights
# 2       -73.896699  4dad975dfa8cf64d804b25e9  Kingsbridge Heights
# 3       -73.910358  50bf6001e4b068101192a373  Kingsbridge Heights
# 4       -73.890206  4c8637a847cc224b2343a79f  Kingsbridge Heights
#
#    Neighborhood Latitude  Neighborhood Longitude  rating
# 0              40.870392              -73.901523     8.1
# 1              40.870392              -73.901523     0.0
# 2              40.870392              -73.901523     5.9
# 3              40.870392              -73.901523     0.0
# 4              40.870392              -73.901523     0.0

# %%
#bronx_places=pd.concat([bronx_venues,bronx_coffee],ignore_index=True)

# %%
bronx_coffee.groupby('Neighborhood').count()
# Out:
#                      Venue  Venue category  Venue Latitide  Venue Longitude  \
# Neighborhood
# Kingsbridge Heights      8               8               8                8
#
#                      id  Neighborhood Latitude  Neighborhood Longitude  rating
# Neighborhood
# Kingsbridge Heights   8                      8                       8       8

# %%
bronx_coffee.groupby('Venue category').count()
# Out:
#                 Venue  Venue Latitide  Venue Longitude  id  Neighborhood  \
# Venue category
# Breakfast Spot      1               1                1   1             1
# Coffee Shop         4               4                4   4             4
# Deli / Bodega       1               1                1   1             1
# Diner               1               1                1   1             1
# Food Truck          1               1                1   1             1
#
#                 Neighborhood Latitude  Neighborhood Longitude  rating
# Venue category
# Breakfast Spot                      1                       1       1
# Coffee Shop                         4                       4       4
# Deli / Bodega                       1                       1       1
# Diner                               1                       1       1
# Food Truck                          1                       1       1

# %% [markdown]
# ### 3. Brooklyn

# %%
brooklyn_data = neighborhoods[neighborhoods['Borough'] == 'Brooklyn'].reset_index(drop=True)
brooklyn_data.head()
# Out:
#     Borough Neighborhood   Latitude  Longitude
# 0  Brooklyn    Bay Ridge  40.625801 -74.030621
# 1  Brooklyn  Bensonhurst  40.611009 -73.995180
# 2  Brooklyn  Sunset Park  40.645103 -74.010316
# 3  Brooklyn   Greenpoint  40.730201 -73.954241
# 4  Brooklyn    Gravesend  40.595260 -73.973471

# %%
address = 'Brooklyn, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of brooklyn are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of brooklyn are 40.6501038, -73.9495823.

# %%
# create map of brooklyn using latitude and longitude values
map_brooklyn = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(brooklyn_data['Latitude'], brooklyn_data['Longitude'], brooklyn_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_brooklyn)  
    
map_brooklyn
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query='coffee'
brooklyn_coffee = getNearbyVenues(names=brooklyn_data['Neighborhood'],
                                   latitudes=brooklyn_data['Latitude'],
                                   longitudes=brooklyn_data['Longitude'])
# Out:
# Bay Ridge
# Bensonhurst
# Sunset Park
# Greenpoint
# Gravesend
# Brighton Beach
# Sheepshead Bay
# Manhattan Terrace
# Flatbush
# Crown Heights
# East Flatbush
# Kensington
# Windsor Terrace
# Prospect Heights
# Brownsville
# Williamsburg
# Bushwick
# Bedford Stuyvesant
# Brooklyn Heights
# Cobble Hill
# Carroll Gardens
# Red Hook
# Gowanus
# Fort Greene
# Park Slope
# Cypress Hills
# East New York
# Starrett City
# Canarsie
# Flatlands
# Mill Island
# Manhattan Beach
# Coney Island
# Bath Beach
# Borough Park
# Dyker Heights
# Gerritsen Beach
# Marine Park
# Clinton Hill
# Sea Gate
# Downtown
# Boerum Hill
# Prospect Lefferts Gardens
# Ocean Hill
# City Line
# Bergen Beach
# Midwood
# Prospect Park South
# Georgetown
# East Williamsburg
# North Side
# South Side
# Ocean Parkway
# Fort Hamilton
# Ditmas Park
# Wingate
# Rugby
# Remsen Village
# New Lots
# Paerdegat Basin
# Mill Basin
# Fulton Ferry
# Vinegar Hill
# Weeksville
# Broadway Junction
# Dumbo
# Homecrest
# Highland Park
# Madison
# Erasmus
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
ids=brooklyn_coffee['id'].tolist()
score=[]
for vid in ids:
    score.append(get_rating(vid))
brooklyn_coffee['rating']=score

# %%
brooklyn_coffee.head()
# Out:
#                            Venue Venue category  Venue Latitide  \
# 0           Latoya's Coffee Shop    Coffee Shop       40.644966
# 1  First Class Daily Coffee Shop    Coffee Shop       40.651191
#
#    Venue Longitude                        id Neighborhood  \
# 0       -73.948478  4f32795419836c91c7db4d12      Erasmus
# 1       -73.946520  4f322af219836c91c7bcd71c      Erasmus
#
#    Neighborhood Latitude  Neighborhood Longitude  rating
# 0              40.646926              -73.948177       0
# 1              40.646926              -73.948177       0

# %%
brooklyn_coffee.groupby('Neighborhood').count()
# Out:
#               Venue  Venue category  Venue Latitide  Venue Longitude  id  \
# Neighborhood
# Erasmus           2               2               2                2   2
#
#               Neighborhood Latitude  Neighborhood Longitude  rating
# Neighborhood
# Erasmus                           2                       2       2

# %%
brooklyn_coffee.groupby('Venue category').count()
# Out:
#                 Venue  Venue Latitide  Venue Longitude  id  Neighborhood  \
# Venue category
# Coffee Shop         2               2                2   2             2
#
#                 Neighborhood Latitude  Neighborhood Longitude  rating
# Venue category
# Coffee Shop                         2                       2       2

# %% [markdown]
# ### 4.Queens

# %%
queens_data = neighborhoods[neighborhoods['Borough'] == 'Queens'].reset_index(drop=True)
queens_data.head()
# Out:
#   Borough     Neighborhood   Latitude  Longitude
# 0  Queens          Astoria  40.768509 -73.915654
# 1  Queens         Woodside  40.746349 -73.901842
# 2  Queens  Jackson Heights  40.751981 -73.882821
# 3  Queens         Elmhurst  40.744049 -73.881656
# 4  Queens     Howard Beach  40.654225 -73.838138

# %%
address = 'Queens, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of queens are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of queens are 40.7498243, -73.7976337.

# %%
# create map of queens using latitude and longitude values
map_queens = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(queens_data['Latitude'], queens_data['Longitude'], queens_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_queens)  
    
map_queens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query='coffee'
queens_coffee = getNearbyVenues(names=queens_data['Neighborhood'],
                                   latitudes=queens_data['Latitude'],
                                   longitudes=queens_data['Longitude'])
# Out:
# Astoria
# Woodside
# Jackson Heights
# Elmhurst
# Howard Beach
# Corona
# Forest Hills
# Kew Gardens
# Richmond Hill
# Flushing
# Long Island City
# Sunnyside
# East Elmhurst
# Maspeth
# Ridgewood
# Glendale
# Rego Park
# Woodhaven
# Ozone Park
# South Ozone Park
# College Point
# Whitestone
# Bayside
# Auburndale
# Little Neck
# Douglaston
# Glen Oaks
# Bellerose
# Kew Gardens Hills
# Fresh Meadows
# Briarwood
# Jamaica Center
# Oakland Gardens
# Queens Village
# Hollis
# South Jamaica
# St. Albans
# Rochdale
# Springfield Gardens
# Cambria Heights
# Rosedale
# Far Rockaway
# Broad Channel
# Breezy Point
# Steinway
# Beechhurst
# Bay Terrace
# Edgemere
# Arverne
# Rockaway Beach
# Neponsit
# Murray Hill
# Floral Park
# Holliswood
# Jamaica Estates
# Queensboro Hill
# Hillcrest
# Ravenswood
# Lindenwood
# Laurelton
# Lefrak City
# Belle Harbor
# Rockaway Park
# Somerville
# Brookville
# Bellaire
# North Corona
# Forest Hills Gardens
# Jamaica Hills
# Utopia
# Pomonok
# Astoria Heights
# Hunters Point
# Sunnyside Gardens
# Blissville
# Roxbury
# Middle Village
# Malba
# Hammels
# Bayswater
# Queensbridge
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
ids=queens_coffee['id'].tolist()
score=[]
for vid in ids:
    score.append(get_rating(vid))
queens_coffee['rating']=score

# %%
queens_coffee.head()
# Out:
#                              Venue Venue category  Venue Latitide  \
# 0               Joe Coffee Company           Café       40.753312
# 1               Carlos Coffee Shop    Coffee Shop       40.753920
# 2  Mama’s Coffee Shop & Restaurant    Coffee Shop       40.755649
# 3               Rosies Coffee Shop    Coffee Shop       40.751232
# 4                     Birch Coffee    Coffee Shop       40.753138
#
#    Venue Longitude                        id  Neighborhood  \
# 0       -73.940044  5db08b4de555080008a6ffe1  Queensbridge
# 1       -73.942260  4f32763019836c91c7da1c56  Queensbridge
# 2       -73.941760  5d17683fca917c0023dfb1d7  Queensbridge
# 3       -73.944487  4de4efde1f6e3190cd4a0470  Queensbridge
# 4       -73.940526  56377108498ee642752d0355  Queensbridge
#
#    Neighborhood Latitude  Neighborhood Longitude  rating
# 0              40.756091              -73.945631       0
# 1              40.756091              -73.945631       0
# 2              40.756091              -73.945631       0
# 3              40.756091              -73.945631       0
# 4              40.756091              -73.945631       0

# %%
queens_coffee.groupby('Neighborhood').count()
# Out:
#               Venue  Venue category  Venue Latitide  Venue Longitude  id  \
# Neighborhood
# Queensbridge      5               5               5                5   5
#
#               Neighborhood Latitude  Neighborhood Longitude  rating
# Neighborhood
# Queensbridge                      5                       5       5

# %%
queens_coffee.groupby('Venue category').count()
# Out:
#                 Venue  Venue Latitide  Venue Longitude  id  Neighborhood  \
# Venue category
# Café                1               1                1   1             1
# Coffee Shop         4               4                4   4             4
#
#                 Neighborhood Latitude  Neighborhood Longitude  rating
# Venue category
# Café                                1                       1       1
# Coffee Shop                         4                       4       4

# %% [markdown]
# ### 5. Staten Island

# %%
si_data = neighborhoods[neighborhoods['Borough'] == 'Staten Island'].reset_index(drop=True)
si_data.head()
# Out:
#          Borough   Neighborhood   Latitude  Longitude
# 0  Staten Island     St. George  40.644982 -74.079353
# 1  Staten Island   New Brighton  40.640615 -74.087017
# 2  Staten Island      Stapleton  40.626928 -74.077902
# 3  Staten Island       Rosebank  40.615305 -74.069805
# 4  Staten Island  West Brighton  40.631879 -74.107182

# %%
address = 'Staten Island, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of si are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of si are 40.5834557, -74.1496048.

# %%
# create map of si using latitude and longitude values
map_si = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(si_data['Latitude'], si_data['Longitude'], si_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_si)  
    
map_si
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
search_query='coffee'
si_venues = getNearbyVenues(names=si_data['Neighborhood'],
                                   latitudes=si_data['Latitude'],
                                   longitudes=si_data['Longitude'])
# Out:
# St. George
# New Brighton
# Stapleton
# Rosebank
# West Brighton
# Grymes Hill
# Todt Hill
# South Beach
# Port Richmond
# Mariner's Harbor
# Port Ivory
# Castleton Corners
# New Springville
# Travis
# New Dorp
# Oakwood
# Great Kills
# Eltingville
# Annadale
# Woodrow
# Tottenville
# Tompkinsville
# Silver Lake
# Sunnyside
# Park Hill
# Westerleigh
# Graniteville
# Arlington
# Arrochar
# Grasmere
# Old Town
# Dongan Hills
# Midland Beach
# Grant City
# New Dorp Beach
# Bay Terrace
# Huguenot
# Pleasant Plains
# Butler Manor
# Charleston
# Rossville
# Arden Heights
# Greenridge
# Heartland Village
# Chelsea
# Bloomfield
# Bulls Head
# Richmond Town
# Shore Acres
# Clifton
# Concord
# Emerson Hill
# Randall Manor
# Howland Hook
# Elm Park
# Manor Heights
# Willowbrook
# Sandy Ground
# Egbertville
# Prince's Bay
# Lighthouse Hill
# Richmond Valley
# Fox Hills
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-e4f2f85a7506> in <module>
#       2 si_venues = getNearbyVenues(names=si_data['Neighborhood'],
#       3                                    latitudes=si_data['Latitude'],
# ----> 4                                    longitudes=si_data['Longitude'])
#
# <ipython-input-17-432ff6a9c2bf> in getNearbyVenues(names, latitudes, longitudes, radius)
#      22     # keep only columns that include venue name, and anything that is associated with location
#      23     filtered_columns = ['name', 'categories'] +['location.lat','location.lng']
# ---> 24     dataframe_filtered = dataframe.loc[:, filtered_columns]
#      25
#      26     # filter the category for each row
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1287                 continue
#    1288
# -> 1289             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1290
#    1291         return retval
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1593         else:
#    1594             # A collection of keys
# -> 1595             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1596             return self.obj._reindex_with_indexers(
#    1597                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['name', 'categories', 'location.lat', 'location.lng'], dtype='object')] are in the [columns]"

# %% [markdown]
# #### It looks like there is no registered coffee shop in foursuare API  in this borough

# %%
NY_venues=pd.concat([manhattan_venues,bronx_coffee,brooklyn_coffee,queens_coffee],ignore_index=True)

# %%
NY_venues
# Out:
#                               Venue             Venue category  \
# 0           Romeo and Juliet Coffee                Coffee Shop
# 1              Oslo Coffee Roasters                Coffee Shop
# 2                   Clovelly Coffee                Coffee Shop
# 3                   R/GA Coffee Bar                       Café
# 4                Blue Bottle Coffee                Coffee Shop
# 5                      Think Coffee                Coffee Shop
# 6                Old Country Coffee                       Café
# 7                   Champion Coffee                Coffee Shop
# 8           Jack’s Stir Brew Coffee                Coffee Shop
# 9         Exclusive  Coffee & Juice                Coffee Shop
# 10                     Corvo Coffee                Coffee Shop
# 11       The 39th Street Coffee Man                 Food Truck
# 12                  Coffee & Crumbs              Deli / Bodega
# 13                 hermanita coffee  Latin American Restaurant
# 14      Jonny's Panini & Coffee Bar                Coffee Shop
# 15     breakfast -coffee/muffin guy             Breakfast Spot
# 16   Kelli Douglas Worldwide Coffee                       Food
# 17                    Deli & Coffee             Breakfast Spot
# 18               Irish Coffee House                 Restaurant
# 19    R/GA 353 Coffee Bar 1st Floor                       Café
# 20                        Starbucks                Coffee Shop
# 21     National Restaurant & Coffee                      Diner
# 22              Perista Coffee Shop                Coffee Shop
# 23   Kingsbridge Coffee Shop & Deli                Coffee Shop
# 24                      Coffee Cart             Breakfast Spot
# 25        Coffee Cart on Fordham Rd                 Food Truck
# 26             National Coffee Shop                Coffee Shop
# 27                        Starbucks                Coffee Shop
# 28       Bus Stop Convenience Store              Deli / Bodega
# 29             Latoya's Coffee Shop                Coffee Shop
# 30    First Class Daily Coffee Shop                Coffee Shop
# 31               Joe Coffee Company                       Café
# 32               Carlos Coffee Shop                Coffee Shop
# 33  Mama’s Coffee Shop & Restaurant                Coffee Shop
# 34               Rosies Coffee Shop                Coffee Shop
# 35                     Birch Coffee                Coffee Shop
#
#     Venue Latitide  Venue Longitude                        id  \
# 0        40.760726       -73.997724  526d9114498ec8efda93fcce
# 1        40.760512       -73.998985  5c683caaf96b2c00397a8609
# 2        40.753292       -73.996745  5d6165d5716af50008cde370
# 3        40.755948       -73.993659  4b9fe9eef964a520f84937e3
# 4        40.753846       -74.002250  5c8d246c492822003a5a5a6e
# 5        40.752244       -74.001707  55fc450a498ed76a0b227750
# 6        40.754371       -73.998727  5758771d498ecbe6c8cc39c5
# 7        40.754853       -73.993904  5b576a7b625a66002c930db5
# 8        40.754054       -74.002213  5c8d4eb71f8ed6002c94f624
# 9        40.756886       -73.993910  5e5e936636734600081ebbf1
# 10       40.757111       -73.993495  58027e78d67c45aa5a15ca16
# 11       40.753753       -73.999316  4f05b744be7bf2206f0a43bf
# 12       40.755637       -73.993400  4b75901ef964a52059142ee3
# 13       40.755774       -73.994862  5069e3cde4b0b6a07e92d283
# 14       40.755584       -73.994818  53a46354498e7d482877cf67
# 15       40.759088       -73.996016  5194d92d498e5b5c10a9a0f4
# 16       40.755679       -73.993905  4f32b3cf19836c91c7f15b56
# 17       40.759773       -73.995436  516c0afe498ed741f6977a6a
# 18       40.756928       -73.993670  51c5caec498ea39923fa0661
# 19       40.756602       -73.993356  4f8ee9a7e4b0634d3771490e
# 20       40.753748       -73.999314  4b040c7df964a5201d5122e3
# 21       40.873007       -73.889082  4b78a508f964a520b4db2ee3
# 22       40.868314       -73.901298  5156f35be4b0dc046e1af723
# 23       40.867210       -73.896699  4dad975dfa8cf64d804b25e9
# 24       40.874555       -73.910358  50bf6001e4b068101192a373
# 25       40.861292       -73.890206  4c8637a847cc224b2343a79f
# 26       40.872841       -73.889053  4fe48299e4b06b1c063a2c33
# 27       40.873234       -73.908730  4b292e73f964a5207b9a24e3
# 28       40.879541       -73.905327  4df96fe0b0fb0401c7f57c23
# 29       40.644966       -73.948478  4f32795419836c91c7db4d12
# 30       40.651191       -73.946520  4f322af219836c91c7bcd71c
# 31       40.753312       -73.940044  5db08b4de555080008a6ffe1
# 32       40.753920       -73.942260  4f32763019836c91c7da1c56
# 33       40.755649       -73.941760  5d17683fca917c0023dfb1d7
# 34       40.751232       -73.944487  4de4efde1f6e3190cd4a0470
# 35       40.753138       -73.940526  56377108498ee642752d0355
#
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  rating
# 0          Hudson Yards              40.756658              -74.000111     7.5
# 1          Hudson Yards              40.756658              -74.000111     8.3
# 2          Hudson Yards              40.756658              -74.000111     7.7
# 3          Hudson Yards              40.756658              -74.000111     0.0
# 4          Hudson Yards              40.756658              -74.000111     7.4
# 5          Hudson Yards              40.756658              -74.000111     7.8
# 6          Hudson Yards              40.756658              -74.000111     7.7
# 7          Hudson Yards              40.756658              -74.000111     0.0
# 8          Hudson Yards              40.756658              -74.000111     6.1
# 9          Hudson Yards              40.756658              -74.000111     0.0
# 10         Hudson Yards              40.756658              -74.000111     6.4
# 11         Hudson Yards              40.756658              -74.000111     0.0
# 12         Hudson Yards              40.756658              -74.000111     0.0
# 13         Hudson Yards              40.756658              -74.000111     0.0
# 14         Hudson Yards              40.756658              -74.000111     7.4
# 15         Hudson Yards              40.756658              -74.000111     0.0
# 16         Hudson Yards              40.756658              -74.000111     0.0
# 17         Hudson Yards              40.756658              -74.000111     0.0
# 18         Hudson Yards              40.756658              -74.000111     0.0
# 19         Hudson Yards              40.756658              -74.000111     0.0
# 20         Hudson Yards              40.756658              -74.000111     6.2
# 21  Kingsbridge Heights              40.870392              -73.901523     8.1
# 22  Kingsbridge Heights              40.870392              -73.901523     0.0
# 23  Kingsbridge Heights              40.870392              -73.901523     5.9
# 24  Kingsbridge Heights              40.870392              -73.901523     0.0
# 25  Kingsbridge Heights              40.870392              -73.901523     0.0
# 26  Kingsbridge Heights              40.870392              -73.901523     0.0
# 27  Kingsbridge Heights              40.870392              -73.901523     0.0
# 28  Kingsbridge Heights              40.870392              -73.901523     0.0
# 29              Erasmus              40.646926              -73.948177     0.0
# 30              Erasmus              40.646926              -73.948177     0.0
# 31         Queensbridge              40.756091              -73.945631     0.0
# 32         Queensbridge              40.756091              -73.945631     0.0
# 33         Queensbridge              40.756091              -73.945631     0.0
# 34         Queensbridge              40.756091              -73.945631     0.0
# 35         Queensbridge              40.756091              -73.945631     0.0

# %% [markdown]
# ### Clustering

# %%
# one hot encoding
NY_onehot = pd.get_dummies(NY_venues[['Venue category']], prefix="", prefix_sep="")

# add Neighborhood column back to dataframe
NY_onehot['Venue Longitude'] = NY_venues['Venue Longitude'] 
NY_onehot['Venue Latitide'] = NY_venues['Venue Latitide'] 
NY_onehot['rating'] = NY_venues['rating'] 
NY_onehot['Neighborhood'] = NY_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [NY_onehot.columns[-1]] + list(NY_onehot.columns[:-1])
NY_onehot = NY_onehot[fixed_columns]

# Check returned one hot encoding data:
print('One hot encoding returned "{}" rows.'.format(NY_onehot.shape[0]))

# Regroup rows by Neighborhood and mean of frequency occurrence per category.
NY_grouped = NY_onehot.groupby('Neighborhood').mean().reset_index()

print('One hot encoding re-group returned "{}" rows.'.format(NY_grouped.shape[0]))
NY_grouped.head()
# Out:
# One hot encoding returned "36" rows.
# One hot encoding re-group returned "4" rows.
#           Neighborhood  Breakfast Spot      Café  Coffee Shop  Deli / Bodega  \
# 0              Erasmus        0.000000  0.000000      1.00000       0.000000
# 1         Hudson Yards        0.095238  0.142857      0.52381       0.047619
# 2  Kingsbridge Heights        0.125000  0.000000      0.50000       0.125000
# 3         Queensbridge        0.000000  0.200000      0.80000       0.000000
#
#    Diner      Food  Food Truck  Latin American Restaurant  Restaurant  \
# 0  0.000  0.000000    0.000000                   0.000000    0.000000
# 1  0.000  0.047619    0.047619                   0.047619    0.047619
# 2  0.125  0.000000    0.125000                   0.000000    0.000000
# 3  0.000  0.000000    0.000000                   0.000000    0.000000
#
#    Venue Longitude  Venue Latitide    rating
# 0       -73.947499       40.648078  0.000000
# 1       -73.996543       40.756020  3.452381
# 2       -73.898844       40.871249  1.750000
# 3       -73.941815       40.753450  0.000000

# %%
NY_grouped2=NY_grouped.drop(['Venue Longitude','Venue Latitide','rating'],axis=1)
for hood in NY_grouped2['Neighborhood']:
    print("----"+hood+"----")
    temp = NY_grouped2[NY_grouped2['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head())
    print('\n')
# Out:
# ----Erasmus----
#             venue  freq
# 0     Coffee Shop   1.0
# 1  Breakfast Spot   0.0
# 2            Café   0.0
# 3   Deli / Bodega   0.0
# 4           Diner   0.0
#
#
# ----Hudson Yards----
#             venue  freq
# 0     Coffee Shop  0.52
# 1            Café  0.14
# 2  Breakfast Spot  0.10
# 3   Deli / Bodega  0.05
# 4            Food  0.05
#
#
# ----Kingsbridge Heights----
#             venue  freq
# 0     Coffee Shop  0.50
# 1  Breakfast Spot  0.12
# 2   Deli / Bodega  0.12
# 3           Diner  0.12
# 4      Food Truck  0.12
#
#
# ----Queensbridge----
#             venue  freq
# 0     Coffee Shop   0.8
# 1            Café   0.2
# 2  Breakfast Spot   0.0
# 3   Deli / Bodega   0.0
# 4           Diner   0.0

# %%
# Function to return most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = NY_grouped2['Neighborhood']

for ind in np.arange(NY_grouped2.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(NY_grouped2.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#           Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0              Erasmus           Coffee Shop            Restaurant
# 1         Hudson Yards           Coffee Shop                  Café
# 2  Kingsbridge Heights           Coffee Shop            Food Truck
# 3         Queensbridge           Coffee Shop                  Café
#
#        3rd Most Common Venue      4th Most Common Venue  \
# 0  Latin American Restaurant                 Food Truck
# 1             Breakfast Spot                 Restaurant
# 2                      Diner              Deli / Bodega
# 3                 Restaurant  Latin American Restaurant
#
#        5th Most Common Venue
# 0                       Food
# 1  Latin American Restaurant
# 2             Breakfast Spot
# 3                 Food Truck

# %% [markdown]
# ### Clustering

# %%
# set number of clusters
kclusters = 3

NY_grouped_clustering = NY_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0)
kmeans.fit(NY_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 2, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

NY_merged = NY_venues
NY_merged = NY_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

NY_merged.tail()
# Out:
#                               Venue Venue category  Venue Latitide  \
# 31               Joe Coffee Company           Café       40.753312
# 32               Carlos Coffee Shop    Coffee Shop       40.753920
# 33  Mama’s Coffee Shop & Restaurant    Coffee Shop       40.755649
# 34               Rosies Coffee Shop    Coffee Shop       40.751232
# 35                     Birch Coffee    Coffee Shop       40.753138
#
#     Venue Longitude                        id  Neighborhood  \
# 31       -73.940044  5db08b4de555080008a6ffe1  Queensbridge
# 32       -73.942260  4f32763019836c91c7da1c56  Queensbridge
# 33       -73.941760  5d17683fca917c0023dfb1d7  Queensbridge
# 34       -73.944487  4de4efde1f6e3190cd4a0470  Queensbridge
# 35       -73.940526  56377108498ee642752d0355  Queensbridge
#
#     Neighborhood Latitude  Neighborhood Longitude  rating  Cluster Labels  \
# 31              40.756091              -73.945631     0.0               0
# 32              40.756091              -73.945631     0.0               0
# 33              40.756091              -73.945631     0.0               0
# 34              40.756091              -73.945631     0.0               0
# 35              40.756091              -73.945631     0.0               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 31           Coffee Shop                  Café            Restaurant
# 32           Coffee Shop                  Café            Restaurant
# 33           Coffee Shop                  Café            Restaurant
# 34           Coffee Shop                  Café            Restaurant
# 35           Coffee Shop                  Café            Restaurant
#
#         4th Most Common Venue 5th Most Common Venue
# 31  Latin American Restaurant            Food Truck
# 32  Latin American Restaurant            Food Truck
# 33  Latin American Restaurant            Food Truck
# 34  Latin American Restaurant            Food Truck
# 35  Latin American Restaurant            Food Truck

# %%
map_clusters = folium.Map(location=[lat, long], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(NY_merged['Neighborhood Latitude'], NY_merged['Neighborhood Longitude'], NY_merged['Neighborhood'], NY_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters
# ***Cluster 0***

# %%
NY_merged.loc[NY_merged['Cluster Labels'] == 0, NY_merged.columns[[1] + list(range(3, NY_merged.shape[1]))]]
# Out:
#    Venue category  Venue Longitude                        id  Neighborhood  \
# 29    Coffee Shop       -73.948478  4f32795419836c91c7db4d12       Erasmus
# 30    Coffee Shop       -73.946520  4f322af219836c91c7bcd71c       Erasmus
# 31           Café       -73.940044  5db08b4de555080008a6ffe1  Queensbridge
# 32    Coffee Shop       -73.942260  4f32763019836c91c7da1c56  Queensbridge
# 33    Coffee Shop       -73.941760  5d17683fca917c0023dfb1d7  Queensbridge
# 34    Coffee Shop       -73.944487  4de4efde1f6e3190cd4a0470  Queensbridge
# 35    Coffee Shop       -73.940526  56377108498ee642752d0355  Queensbridge
#
#     Neighborhood Latitude  Neighborhood Longitude  rating  Cluster Labels  \
# 29              40.646926              -73.948177     0.0               0
# 30              40.646926              -73.948177     0.0               0
# 31              40.756091              -73.945631     0.0               0
# 32              40.756091              -73.945631     0.0               0
# 33              40.756091              -73.945631     0.0               0
# 34              40.756091              -73.945631     0.0               0
# 35              40.756091              -73.945631     0.0               0
#
#    1st Most Common Venue 2nd Most Common Venue      3rd Most Common Venue  \
# 29           Coffee Shop            Restaurant  Latin American Restaurant
# 30           Coffee Shop            Restaurant  Latin American Restaurant
# 31           Coffee Shop                  Café                 Restaurant
# 32           Coffee Shop                  Café                 Restaurant
# 33           Coffee Shop                  Café                 Restaurant
# 34           Coffee Shop                  Café                 Restaurant
# 35           Coffee Shop                  Café                 Restaurant
#
#         4th Most Common Venue 5th Most Common Venue
# 29                 Food Truck                  Food
# 30                 Food Truck                  Food
# 31  Latin American Restaurant            Food Truck
# 32  Latin American Restaurant            Food Truck
# 33  Latin American Restaurant            Food Truck
# 34  Latin American Restaurant            Food Truck
# 35  Latin American Restaurant            Food Truck

# %% [markdown]
# ***It looks like all venues which are not rated are in this category***

# %% [markdown]
# ### Cluster 1

# %%
NY_merged.loc[NY_merged['Cluster Labels'] == 1, NY_merged.columns[[1] + list(range(3, NY_merged.shape[1]))]]
# Out:
#                Venue category  Venue Longitude                        id  \
# 0                 Coffee Shop       -73.997724  526d9114498ec8efda93fcce
# 1                 Coffee Shop       -73.998985  5c683caaf96b2c00397a8609
# 2                 Coffee Shop       -73.996745  5d6165d5716af50008cde370
# 3                        Café       -73.993659  4b9fe9eef964a520f84937e3
# 4                 Coffee Shop       -74.002250  5c8d246c492822003a5a5a6e
# 5                 Coffee Shop       -74.001707  55fc450a498ed76a0b227750
# 6                        Café       -73.998727  5758771d498ecbe6c8cc39c5
# 7                 Coffee Shop       -73.993904  5b576a7b625a66002c930db5
# 8                 Coffee Shop       -74.002213  5c8d4eb71f8ed6002c94f624
# 9                 Coffee Shop       -73.993910  5e5e936636734600081ebbf1
# 10                Coffee Shop       -73.993495  58027e78d67c45aa5a15ca16
# 11                 Food Truck       -73.999316  4f05b744be7bf2206f0a43bf
# 12              Deli / Bodega       -73.993400  4b75901ef964a52059142ee3
# 13  Latin American Restaurant       -73.994862  5069e3cde4b0b6a07e92d283
# 14                Coffee Shop       -73.994818  53a46354498e7d482877cf67
# 15             Breakfast Spot       -73.996016  5194d92d498e5b5c10a9a0f4
# 16                       Food       -73.993905  4f32b3cf19836c91c7f15b56
# 17             Breakfast Spot       -73.995436  516c0afe498ed741f6977a6a
# 18                 Restaurant       -73.993670  51c5caec498ea39923fa0661
# 19                       Café       -73.993356  4f8ee9a7e4b0634d3771490e
# 20                Coffee Shop       -73.999314  4b040c7df964a5201d5122e3
#
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  rating  \
# 0   Hudson Yards              40.756658              -74.000111     7.5
# 1   Hudson Yards              40.756658              -74.000111     8.3
# 2   Hudson Yards              40.756658              -74.000111     7.7
# 3   Hudson Yards              40.756658              -74.000111     0.0
# 4   Hudson Yards              40.756658              -74.000111     7.4
# 5   Hudson Yards              40.756658              -74.000111     7.8
# 6   Hudson Yards              40.756658              -74.000111     7.7
# 7   Hudson Yards              40.756658              -74.000111     0.0
# 8   Hudson Yards              40.756658              -74.000111     6.1
# 9   Hudson Yards              40.756658              -74.000111     0.0
# 10  Hudson Yards              40.756658              -74.000111     6.4
# 11  Hudson Yards              40.756658              -74.000111     0.0
# 12  Hudson Yards              40.756658              -74.000111     0.0
# 13  Hudson Yards              40.756658              -74.000111     0.0
# 14  Hudson Yards              40.756658              -74.000111     7.4
# 15  Hudson Yards              40.756658              -74.000111     0.0
# 16  Hudson Yards              40.756658              -74.000111     0.0
# 17  Hudson Yards              40.756658              -74.000111     0.0
# 18  Hudson Yards              40.756658              -74.000111     0.0
# 19  Hudson Yards              40.756658              -74.000111     0.0
# 20  Hudson Yards              40.756658              -74.000111     6.2
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0                1           Coffee Shop                  Café
# 1                1           Coffee Shop                  Café
# 2                1           Coffee Shop                  Café
# 3                1           Coffee Shop                  Café
# 4                1           Coffee Shop                  Café
# 5                1           Coffee Shop                  Café
# 6                1           Coffee Shop                  Café
# 7                1           Coffee Shop                  Café
# 8                1           Coffee Shop                  Café
# 9                1           Coffee Shop                  Café
# 10               1           Coffee Shop                  Café
# 11               1           Coffee Shop                  Café
# 12               1           Coffee Shop                  Café
# 13               1           Coffee Shop                  Café
# 14               1           Coffee Shop                  Café
# 15               1           Coffee Shop                  Café
# 16               1           Coffee Shop                  Café
# 17               1           Coffee Shop                  Café
# 18               1           Coffee Shop                  Café
# 19               1           Coffee Shop                  Café
# 20               1           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue
# 0         Breakfast Spot            Restaurant  Latin American Restaurant
# 1         Breakfast Spot            Restaurant  Latin American Restaurant
# 2         Breakfast Spot            Restaurant  Latin American Restaurant
# 3         Breakfast Spot            Restaurant  Latin American Restaurant
# 4         Breakfast Spot            Restaurant  Latin American Restaurant
# 5         Breakfast Spot            Restaurant  Latin American Restaurant
# 6         Breakfast Spot            Restaurant  Latin American Restaurant
# 7         Breakfast Spot            Restaurant  Latin American Restaurant
# 8         Breakfast Spot            Restaurant  Latin American Restaurant
# 9         Breakfast Spot            Restaurant  Latin American Restaurant
# 10        Breakfast Spot            Restaurant  Latin American Restaurant
# 11        Breakfast Spot            Restaurant  Latin American Restaurant
# 12        Breakfast Spot            Restaurant  Latin American Restaurant
# 13        Breakfast Spot            Restaurant  Latin American Restaurant
# 14        Breakfast Spot            Restaurant  Latin American Restaurant
# 15        Breakfast Spot            Restaurant  Latin American Restaurant
# 16        Breakfast Spot            Restaurant  Latin American Restaurant
# 17        Breakfast Spot            Restaurant  Latin American Restaurant
# 18        Breakfast Spot            Restaurant  Latin American Restaurant
# 19        Breakfast Spot            Restaurant  Latin American Restaurant
# 20        Breakfast Spot            Restaurant  Latin American Restaurant

# %% [markdown]
# ***As Hudson Yards the most popular place for coffee shops,it has created seperate cluster***

# %% [markdown]
# ### Cluster 2

# %%
NY_merged.loc[NY_merged['Cluster Labels'] == 2, NY_merged.columns[[1] + list(range(3, NY_merged.shape[1]))]]
# Out:
#     Venue category  Venue Longitude                        id  \
# 21           Diner       -73.889082  4b78a508f964a520b4db2ee3
# 22     Coffee Shop       -73.901298  5156f35be4b0dc046e1af723
# 23     Coffee Shop       -73.896699  4dad975dfa8cf64d804b25e9
# 24  Breakfast Spot       -73.910358  50bf6001e4b068101192a373
# 25      Food Truck       -73.890206  4c8637a847cc224b2343a79f
# 26     Coffee Shop       -73.889053  4fe48299e4b06b1c063a2c33
# 27     Coffee Shop       -73.908730  4b292e73f964a5207b9a24e3
# 28   Deli / Bodega       -73.905327  4df96fe0b0fb0401c7f57c23
#
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 21  Kingsbridge Heights              40.870392              -73.901523
# 22  Kingsbridge Heights              40.870392              -73.901523
# 23  Kingsbridge Heights              40.870392              -73.901523
# 24  Kingsbridge Heights              40.870392              -73.901523
# 25  Kingsbridge Heights              40.870392              -73.901523
# 26  Kingsbridge Heights              40.870392              -73.901523
# 27  Kingsbridge Heights              40.870392              -73.901523
# 28  Kingsbridge Heights              40.870392              -73.901523
#
#     rating  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 21     8.1               2           Coffee Shop            Food Truck
# 22     0.0               2           Coffee Shop            Food Truck
# 23     5.9               2           Coffee Shop            Food Truck
# 24     0.0               2           Coffee Shop            Food Truck
# 25     0.0               2           Coffee Shop            Food Truck
# 26     0.0               2           Coffee Shop            Food Truck
# 27     0.0               2           Coffee Shop            Food Truck
# 28     0.0               2           Coffee Shop            Food Truck
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue
# 21                 Diner         Deli / Bodega        Breakfast Spot
# 22                 Diner         Deli / Bodega        Breakfast Spot
# 23                 Diner         Deli / Bodega        Breakfast Spot
# 24                 Diner         Deli / Bodega        Breakfast Spot
# 25                 Diner         Deli / Bodega        Breakfast Spot
# 26                 Diner         Deli / Bodega        Breakfast Spot
# 27                 Diner         Deli / Bodega        Breakfast Spot
# 28                 Diner         Deli / Bodega        Breakfast Spot

# %% [markdown]
# ***The second most popular place is Kingsbridge Heights***

# %% [markdown]
# ## Let's try to find coffee shops for 2 persons, which will be more or less equal distanced for both of them

# %%
# Address of first person
address = '292 Greenwich St, New York, NY 10007'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.71596 -74.0112857

# %%
# A little modification of this function 
def getNearbyVenues2(latitude,longitude,radius=500):
            
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET,  
        latitude, 
        longitude, 
        VERSION,
        search_query,
        radius, 
        LIMIT)

        # make the GET request
    results = requests.get(url).json()["response"]['venues']
        
    dataframe = json_normalize(results)
    # keep only columns that include venue name, and anything that is associated with location
    filtered_columns = ['name', 'categories'] +['location.lat','location.lng', 'location.address']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

    dataframe_filtered=dataframe_filtered.rename(columns={"name": "Venue", "categories": "Venue category",'location.lat': 'Venue Latitide', 'location.lng':'Venue Longitude','location.address':'Address' })              
    return(dataframe_filtered)

# %%
# Looking for coffee shops around
search_query='coffee'
dataframe_filtered= getNearbyVenues2(latitude,longitude)
dataframe_filtered
# Out:
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                    Venue             Venue category  \
# 0               For Five Coffee Roasters                Coffee Shop
# 1                  Blue Spoon Coffee Co.                Coffee Shop
# 2            Hudson/Chambers Coffee Cart                 Food Truck
# 3              Laughing Man Coffee & Tea                Coffee Shop
# 4                Jack’s Stir Brew Coffee                Coffee Shop
# 5                     Blue Bottle Coffee                Coffee Shop
# 6                            Coffee Cart                Coffee Shop
# 7                   Sky Lobby Coffee Bar        Corporate Cafeteria
# 8                             Joe Coffee                Coffee Shop
# 9                   3rd Floor Coffee Bar      Corporate Coffee Shop
# 10             Laughing Man Coffee & Tea                Coffee Shop
# 11                    Le District Coffee                Coffee Shop
# 12               MBJ Coffee Kiosk @ BMCC                       Café
# 13                           Coffee Shop                       Café
# 14           Coffee Cuisine of Church St                       Food
# 15  Coffee by La Colombe Coffee Roasters      Corporate Coffee Shop
# 16                    The Coffee Beanery                Coffee Shop
# 17                          I m a coffee                       Café
# 18                           Coffee Cart                 Food Court
# 19                           Coffee Cart                 Food Truck
# 20                  Coffee &  Donut Cart                 Food Truck
# 21           Lafayette/Worth Coffee Cart                 Food Truck
# 22                        Coffee & Lunch  Cajun / Creole Restaurant
# 23                           Coffee Cart                Coffee Shop
# 24                           coffee cart             Breakfast Spot
# 25                38th floor coffee cart                Coffee Shop
# 26                          Sam's Coffee                 Food Truck
# 27                        Supreme Coffee                 Food Truck
# 28                      sams coffee cart                 Food Truck
# 29               Mr. Akram's Coffee Cart                 Food Truck
# 30                  george howell coffee                Coffee Shop
# 31                      Nobletree Coffee                Coffee Shop
# 32                    Mary's Coffee Shop                Coffee Shop
# 33                             Starbucks                Coffee Shop
# 34                             Starbucks                Coffee Shop
# 35                             Starbucks                Coffee Shop
# 36                             Starbucks                Coffee Shop
# 37                             Starbucks                Coffee Shop
# 38                             Starbucks                Coffee Shop
# 39                 The Bar at Condé Nast      Corporate Coffee Shop
#
#     Venue Latitide  Venue Longitude                              Address
# 0        40.712240       -74.014915                                  NaN
# 1        40.714428       -74.006859                       76 Chambers St
# 2        40.715638       -74.009613                          Chambers St
# 3        40.717394       -74.010103                         184 Duane St
# 4        40.716450       -74.009755                         139 Reade St
# 5        40.710589       -74.012371                     150 Greenwich St
# 6        40.715331       -74.011562                                  NaN
# 7        40.714708       -74.014404                          200 West St
# 8        40.712526       -74.013137                       Oculus Passage
# 9        40.714757       -74.014329                          200 West St
# 10       40.714754       -74.017368                          1 N End Ave
# 11       40.713284       -74.015854                       225 Liberty St
# 12       40.716990       -74.012021  199 Chambers St, New York, NY 10013
# 13       40.718039       -74.008331                                  NaN
# 14       40.712952       -74.009491                        100 Church St
# 15       40.713416       -74.015191                                  NaN
# 16       40.714629       -74.015819                         30 Mall Dr W
# 17       40.714289       -74.010661                     9 Saint Marks Pl
# 18       40.719252       -74.008515            Hudson St and Franklin St
# 19       40.717064       -74.006391         W. Broadway  & Thomas Street
# 20       40.712689       -74.009985                           Barclay st
# 21       40.714751       -74.004314                         125 Worth St
# 22       40.711542       -74.012841                     185 Greenwich St
# 23       40.720350       -74.010357                  Greenwich & N.Moore
# 24       40.711786       -74.009093     222 Broadway, New York, NY 10038
# 25       40.714011       -74.013645                         200 Vesey St
# 26       40.716706       -74.006250                       214 Church St.
# 27       40.716884       -74.005879                          60 Worth St
# 28       40.714269       -74.005973                              43th st
# 29       40.718953       -74.006673                                  NaN
# 30       40.718582       -74.005577                      102 Franklin St
# 31       40.710470       -74.011690                  21 Cortlandt Street
# 32       40.712786       -74.005944                   25-15 Queens Plz N
# 33       40.715534       -74.009030                      125 Chambers St
# 34       40.710922       -74.010284                         195 Broadway
# 35       40.720729       -74.011210                     388 Greenwich St
# 36       40.712204       -74.008052                         233 Broadway
# 37       40.711598       -74.006726                          38 Park Row
# 38       40.714855       -74.005936                         291 Broadway
# 39       40.712703       -74.013260                        285 Fulton St

# %% [markdown]
# ### Showing these locations on map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add a red circle marker to represent the 1st person location
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Your location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered['Venue Latitide'], dataframe_filtered['Venue Longitude'], dataframe_filtered['Venue category']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Address of second person

# %%
address2 = '70 Thomas St, New York, NY 10013, USA'

geolocator2 = Nominatim(user_agent="foursquare_agent")
location2 = geolocator.geocode(address2)
latitude2 = location2.latitude
longitude2 = location2.longitude
print(latitude2, longitude2)
# Out:
# 40.71685275 -74.00771469641813

# %%
# Looking for coffee shops around
search_query='coffee'
dataframe_filtered2= getNearbyVenues2(latitude2,longitude2)
dataframe_filtered2
# Out:
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                                  Venue             Venue category  \
# 0                Blue Spoon Coffee Co.                Coffee Shop
# 1          Hudson/Chambers Coffee Cart                 Food Truck
# 2                          Coffee Cart                Coffee Shop
# 3                West Side Coffee Shop  Latin American Restaurant
# 4   Dunkin' Iced Coffee Lounge at Z100                Music Venue
# 5            Laughing Man Coffee & Tea                Coffee Shop
# 6              Jack’s Stir Brew Coffee                Coffee Shop
# 7                          Coffee Cart                 Food Truck
# 8                   Blue Bottle Coffee                Coffee Shop
# 9                          Coffee Shop                       Café
# 10                        Think Coffee                Coffee Shop
# 11         Lafayette/Worth Coffee Cart                 Food Truck
# 12                         Coffee Cart                 Food Court
# 13                        Sam's Coffee                 Food Truck
# 14                      Supreme Coffee                 Food Truck
# 15                      The Coffee Man                 Food Truck
# 16                         Coffee Cart                Coffee Shop
# 17         Coffee Cuisine of Church St                       Food
# 18                         Coffee Cart                Coffee Shop
# 19                        Coffee Cento                       Café
# 20                       Coffee Studio                Coffee Shop
# 21                       Sawada Coffee                Coffee Shop
# 22                george howell coffee                Coffee Shop
# 23             Mr. Akram's Coffee Cart                 Food Truck
# 24                Coffee &  Donut Cart                 Food Truck
# 25                    sams coffee cart                 Food Truck
# 26             MBJ Coffee Kiosk @ BMCC                       Café
# 27                        I m a coffee                       Café
# 28                  Mary's Coffee Shop                Coffee Shop
# 29              38th floor coffee cart                Coffee Shop
# 30                   Illy Coffee Stand                       Café
# 31                           Starbucks                Coffee Shop
# 32                           Starbucks                Coffee Shop
# 33             La Colombe Torrefaction                Coffee Shop
# 34                           Starbucks                Coffee Shop
# 35                    Jack's Stir Brew                Coffee Shop
# 36                           Starbucks                Coffee Shop
# 37                           Starbucks                Coffee Shop
# 38                           Starbucks                Coffee Shop
# 39                      Cafe Lafayette              Deli / Bodega
# 40                           Starbucks                Coffee Shop
#
#     Venue Latitide  Venue Longitude                              Address
# 0        40.714428       -74.006859                       76 Chambers St
# 1        40.715638       -74.009613                          Chambers St
# 2        40.714389       -74.002791                         60 Centre St
# 3        40.720174       -74.003915                        323 Church St
# 4        40.720000       -74.004561                                  NaN
# 5        40.717394       -74.010103                         184 Duane St
# 6        40.716450       -74.009755                         139 Reade St
# 7        40.717064       -74.006391         W. Broadway  & Thomas Street
# 8        40.718355       -74.002215                         396 Broadway
# 9        40.718039       -74.008331                                  NaN
# 10       40.716909       -74.003934                         348 Broadway
# 11       40.714751       -74.004314                         125 Worth St
# 12       40.719252       -74.008515            Hudson St and Franklin St
# 13       40.716706       -74.006250                       214 Church St.
# 14       40.716884       -74.005879                          60 Worth St
# 15       40.718724       -74.002811                                  NaN
# 16       40.715331       -74.011562                                  NaN
# 17       40.712952       -74.009491                        100 Church St
# 18       40.720350       -74.010357                  Greenwich & N.Moore
# 19       40.717815       -74.001106                     100 Lafayette St
# 20       40.717858       -74.001077                     100 Lafayette St
# 21       40.718068       -74.002001                   33 Cortlandt Alley
# 22       40.718582       -74.005577                      102 Franklin St
# 23       40.718953       -74.006673                                  NaN
# 24       40.712689       -74.009985                           Barclay st
# 25       40.714269       -74.005973                              43th st
# 26       40.716990       -74.012021  199 Chambers St, New York, NY 10013
# 27       40.714289       -74.010661                     9 Saint Marks Pl
# 28       40.712786       -74.005944                   25-15 Queens Plz N
# 29       40.714011       -74.013645                         200 Vesey St
# 30       40.721395       -74.011297                     390 Greenwich St
# 31       40.715534       -74.009030                      125 Chambers St
# 32       40.714855       -74.005936                         291 Broadway
# 33       40.719829       -74.003854                        319 Church St
# 34       40.715714       -74.003154                         111 Worth St
# 35       40.719352       -74.005075                        West Broadway
# 36       40.720729       -74.011210                     388 Greenwich St
# 37       40.712204       -74.008052                         233 Broadway
# 38       40.711598       -74.006726                          38 Park Row
# 39       40.717206       -74.001775                      80 Lafayette St
# 40       40.718802       -74.002431                         405 Broadway

# %%
venues_map = folium.Map(location=[latitude2, longitude2], zoom_start=13) 
# add a red circle marker to represent 2nd person's location
folium.features.CircleMarker(
    [latitude2, longitude2],
    radius=10,
    color='red',
    popup='Partners location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered2['Venue Latitide'], dataframe_filtered2['Venue Longitude'], dataframe_filtered2['Venue category']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NOW we are going to check common places for these 2 locations

# %%
res=pd.concat([dataframe_filtered,dataframe_filtered2],ignore_index=True)
res
# Out:
#                                    Venue             Venue category  \
# 0               For Five Coffee Roasters                Coffee Shop
# 1                  Blue Spoon Coffee Co.                Coffee Shop
# 2            Hudson/Chambers Coffee Cart                 Food Truck
# 3              Laughing Man Coffee & Tea                Coffee Shop
# 4                Jack’s Stir Brew Coffee                Coffee Shop
# 5                     Blue Bottle Coffee                Coffee Shop
# 6                            Coffee Cart                Coffee Shop
# 7                   Sky Lobby Coffee Bar        Corporate Cafeteria
# 8                             Joe Coffee                Coffee Shop
# 9                   3rd Floor Coffee Bar      Corporate Coffee Shop
# 10             Laughing Man Coffee & Tea                Coffee Shop
# 11                    Le District Coffee                Coffee Shop
# 12               MBJ Coffee Kiosk @ BMCC                       Café
# 13                           Coffee Shop                       Café
# 14           Coffee Cuisine of Church St                       Food
# 15  Coffee by La Colombe Coffee Roasters      Corporate Coffee Shop
# 16                    The Coffee Beanery                Coffee Shop
# 17                          I m a coffee                       Café
# 18                           Coffee Cart                 Food Court
# 19                           Coffee Cart                 Food Truck
# 20                  Coffee &  Donut Cart                 Food Truck
# 21           Lafayette/Worth Coffee Cart                 Food Truck
# 22                        Coffee & Lunch  Cajun / Creole Restaurant
# 23                           Coffee Cart                Coffee Shop
# 24                           coffee cart             Breakfast Spot
# 25                38th floor coffee cart                Coffee Shop
# 26                          Sam's Coffee                 Food Truck
# 27                        Supreme Coffee                 Food Truck
# 28                      sams coffee cart                 Food Truck
# 29               Mr. Akram's Coffee Cart                 Food Truck
# 30                  george howell coffee                Coffee Shop
# 31                      Nobletree Coffee                Coffee Shop
# 32                    Mary's Coffee Shop                Coffee Shop
# 33                             Starbucks                Coffee Shop
# 34                             Starbucks                Coffee Shop
# 35                             Starbucks                Coffee Shop
# 36                             Starbucks                Coffee Shop
# 37                             Starbucks                Coffee Shop
# 38                             Starbucks                Coffee Shop
# 39                 The Bar at Condé Nast      Corporate Coffee Shop
# 40                 Blue Spoon Coffee Co.                Coffee Shop
# 41           Hudson/Chambers Coffee Cart                 Food Truck
# 42                           Coffee Cart                Coffee Shop
# 43                 West Side Coffee Shop  Latin American Restaurant
# 44    Dunkin' Iced Coffee Lounge at Z100                Music Venue
# 45             Laughing Man Coffee & Tea                Coffee Shop
# 46               Jack’s Stir Brew Coffee                Coffee Shop
# 47                           Coffee Cart                 Food Truck
# 48                    Blue Bottle Coffee                Coffee Shop
# 49                           Coffee Shop                       Café
# 50                          Think Coffee                Coffee Shop
# 51           Lafayette/Worth Coffee Cart                 Food Truck
# 52                           Coffee Cart                 Food Court
# 53                          Sam's Coffee                 Food Truck
# 54                        Supreme Coffee                 Food Truck
# 55                        The Coffee Man                 Food Truck
# 56                           Coffee Cart                Coffee Shop
# 57           Coffee Cuisine of Church St                       Food
# 58                           Coffee Cart                Coffee Shop
# 59                          Coffee Cento                       Café
# 60                         Coffee Studio                Coffee Shop
# 61                         Sawada Coffee                Coffee Shop
# 62                  george howell coffee                Coffee Shop
# 63               Mr. Akram's Coffee Cart                 Food Truck
# 64                  Coffee &  Donut Cart                 Food Truck
# 65                      sams coffee cart                 Food Truck
# 66               MBJ Coffee Kiosk @ BMCC                       Café
# 67                          I m a coffee                       Café
# 68                    Mary's Coffee Shop                Coffee Shop
# 69                38th floor coffee cart                Coffee Shop
# 70                     Illy Coffee Stand                       Café
# 71                             Starbucks                Coffee Shop
# 72                             Starbucks                Coffee Shop
# 73               La Colombe Torrefaction                Coffee Shop
# 74                             Starbucks                Coffee Shop
# 75                      Jack's Stir Brew                Coffee Shop
# 76                             Starbucks                Coffee Shop
# 77                             Starbucks                Coffee Shop
# 78                             Starbucks                Coffee Shop
# 79                        Cafe Lafayette              Deli / Bodega
# 80                             Starbucks                Coffee Shop
#
#     Venue Latitide  Venue Longitude                              Address
# 0        40.712240       -74.014915                                  NaN
# 1        40.714428       -74.006859                       76 Chambers St
# 2        40.715638       -74.009613                          Chambers St
# 3        40.717394       -74.010103                         184 Duane St
# 4        40.716450       -74.009755                         139 Reade St
# 5        40.710589       -74.012371                     150 Greenwich St
# 6        40.715331       -74.011562                                  NaN
# 7        40.714708       -74.014404                          200 West St
# 8        40.712526       -74.013137                       Oculus Passage
# 9        40.714757       -74.014329                          200 West St
# 10       40.714754       -74.017368                          1 N End Ave
# 11       40.713284       -74.015854                       225 Liberty St
# 12       40.716990       -74.012021  199 Chambers St, New York, NY 10013
# 13       40.718039       -74.008331                                  NaN
# 14       40.712952       -74.009491                        100 Church St
# 15       40.713416       -74.015191                                  NaN
# 16       40.714629       -74.015819                         30 Mall Dr W
# 17       40.714289       -74.010661                     9 Saint Marks Pl
# 18       40.719252       -74.008515            Hudson St and Franklin St
# 19       40.717064       -74.006391         W. Broadway  & Thomas Street
# 20       40.712689       -74.009985                           Barclay st
# 21       40.714751       -74.004314                         125 Worth St
# 22       40.711542       -74.012841                     185 Greenwich St
# 23       40.720350       -74.010357                  Greenwich & N.Moore
# 24       40.711786       -74.009093     222 Broadway, New York, NY 10038
# 25       40.714011       -74.013645                         200 Vesey St
# 26       40.716706       -74.006250                       214 Church St.
# 27       40.716884       -74.005879                          60 Worth St
# 28       40.714269       -74.005973                              43th st
# 29       40.718953       -74.006673                                  NaN
# 30       40.718582       -74.005577                      102 Franklin St
# 31       40.710470       -74.011690                  21 Cortlandt Street
# 32       40.712786       -74.005944                   25-15 Queens Plz N
# 33       40.715534       -74.009030                      125 Chambers St
# 34       40.710922       -74.010284                         195 Broadway
# 35       40.720729       -74.011210                     388 Greenwich St
# 36       40.712204       -74.008052                         233 Broadway
# 37       40.711598       -74.006726                          38 Park Row
# 38       40.714855       -74.005936                         291 Broadway
# 39       40.712703       -74.013260                        285 Fulton St
# 40       40.714428       -74.006859                       76 Chambers St
# 41       40.715638       -74.009613                          Chambers St
# 42       40.714389       -74.002791                         60 Centre St
# 43       40.720174       -74.003915                        323 Church St
# 44       40.720000       -74.004561                                  NaN
# 45       40.717394       -74.010103                         184 Duane St
# 46       40.716450       -74.009755                         139 Reade St
# 47       40.717064       -74.006391         W. Broadway  & Thomas Street
# 48       40.718355       -74.002215                         396 Broadway
# 49       40.718039       -74.008331                                  NaN
# 50       40.716909       -74.003934                         348 Broadway
# 51       40.714751       -74.004314                         125 Worth St
# 52       40.719252       -74.008515            Hudson St and Franklin St
# 53       40.716706       -74.006250                       214 Church St.
# 54       40.716884       -74.005879                          60 Worth St
# 55       40.718724       -74.002811                                  NaN
# 56       40.715331       -74.011562                                  NaN
# 57       40.712952       -74.009491                        100 Church St
# 58       40.720350       -74.010357                  Greenwich & N.Moore
# 59       40.717815       -74.001106                     100 Lafayette St
# 60       40.717858       -74.001077                     100 Lafayette St
# 61       40.718068       -74.002001                   33 Cortlandt Alley
# 62       40.718582       -74.005577                      102 Franklin St
# 63       40.718953       -74.006673                                  NaN
# 64       40.712689       -74.009985                           Barclay st
# 65       40.714269       -74.005973                              43th st
# 66       40.716990       -74.012021  199 Chambers St, New York, NY 10013
# 67       40.714289       -74.010661                     9 Saint Marks Pl
# 68       40.712786       -74.005944                   25-15 Queens Plz N
# 69       40.714011       -74.013645                         200 Vesey St
# 70       40.721395       -74.011297                     390 Greenwich St
# 71       40.715534       -74.009030                      125 Chambers St
# 72       40.714855       -74.005936                         291 Broadway
# 73       40.719829       -74.003854                        319 Church St
# 74       40.715714       -74.003154                         111 Worth St
# 75       40.719352       -74.005075                        West Broadway
# 76       40.720729       -74.011210                     388 Greenwich St
# 77       40.712204       -74.008052                         233 Broadway
# 78       40.711598       -74.006726                          38 Park Row
# 79       40.717206       -74.001775                      80 Lafayette St
# 80       40.718802       -74.002431                         405 Broadway

# %% [markdown]
# ### Creating a dataframe with common places

# %%
duplicateRowsDF = res[res.duplicated(['Address'], keep='first')]
duplicateRowsDF=duplicateRowsDF.dropna(subset=['Address']).reset_index()
duplicateRowsDF
# Out:
#     index                        Venue         Venue category  Venue Latitide  \
# 0       9         3rd Floor Coffee Bar  Corporate Coffee Shop       40.714757
# 1      40        Blue Spoon Coffee Co.            Coffee Shop       40.714428
# 2      41  Hudson/Chambers Coffee Cart             Food Truck       40.715638
# 3      45    Laughing Man Coffee & Tea            Coffee Shop       40.717394
# 4      46      Jack’s Stir Brew Coffee            Coffee Shop       40.716450
# 5      47                  Coffee Cart             Food Truck       40.717064
# 6      51  Lafayette/Worth Coffee Cart             Food Truck       40.714751
# 7      52                  Coffee Cart             Food Court       40.719252
# 8      53                 Sam's Coffee             Food Truck       40.716706
# 9      54               Supreme Coffee             Food Truck       40.716884
# 10     57  Coffee Cuisine of Church St                   Food       40.712952
# 11     58                  Coffee Cart            Coffee Shop       40.720350
# 12     60                Coffee Studio            Coffee Shop       40.717858
# 13     62         george howell coffee            Coffee Shop       40.718582
# 14     64         Coffee &  Donut Cart             Food Truck       40.712689
# 15     65             sams coffee cart             Food Truck       40.714269
# 16     66      MBJ Coffee Kiosk @ BMCC                   Café       40.716990
# 17     67                 I m a coffee                   Café       40.714289
# 18     68           Mary's Coffee Shop            Coffee Shop       40.712786
# 19     69       38th floor coffee cart            Coffee Shop       40.714011
# 20     71                    Starbucks            Coffee Shop       40.715534
# 21     72                    Starbucks            Coffee Shop       40.714855
# 22     76                    Starbucks            Coffee Shop       40.720729
# 23     77                    Starbucks            Coffee Shop       40.712204
# 24     78                    Starbucks            Coffee Shop       40.711598
#
#     Venue Longitude                              Address
# 0        -74.014329                          200 West St
# 1        -74.006859                       76 Chambers St
# 2        -74.009613                          Chambers St
# 3        -74.010103                         184 Duane St
# 4        -74.009755                         139 Reade St
# 5        -74.006391         W. Broadway  & Thomas Street
# 6        -74.004314                         125 Worth St
# 7        -74.008515            Hudson St and Franklin St
# 8        -74.006250                       214 Church St.
# 9        -74.005879                          60 Worth St
# 10       -74.009491                        100 Church St
# 11       -74.010357                  Greenwich & N.Moore
# 12       -74.001077                     100 Lafayette St
# 13       -74.005577                      102 Franklin St
# 14       -74.009985                           Barclay st
# 15       -74.005973                              43th st
# 16       -74.012021  199 Chambers St, New York, NY 10013
# 17       -74.010661                     9 Saint Marks Pl
# 18       -74.005944                   25-15 Queens Plz N
# 19       -74.013645                         200 Vesey St
# 20       -74.009030                      125 Chambers St
# 21       -74.005936                         291 Broadway
# 22       -74.011210                     388 Greenwich St
# 23       -74.008052                         233 Broadway
# 24       -74.006726                          38 Park Row

# %% [markdown]
# ### Showing these locations on map

# %%
venues_map = folium.Map(location=[latitude2, longitude2], zoom_start=13) 
# add a red circle marker to represent both location
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Your location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.features.CircleMarker(
    [latitude2, longitude2],
    radius=10,
    color='red',
    popup='Partners location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(duplicateRowsDF['Venue Latitide'], duplicateRowsDF['Venue Longitude'], duplicateRowsDF['Venue category']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Making more universal function, to adapt for long distanced 2 locations

# %%
# Calculating distance between 2 endpoints
def haversine_array(lat1, lng1, lat2, lng2):
    lat1, lng1, lat2, lng2 = map(np.radians, (lat1, lng1, lat2, lng2))
    AVG_EARTH_RADIUS = 6371  # in km
    lat = lat2 - lat1
    lng = lng2 - lng1
    d = np.sin(lat * 0.5) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(lng * 0.5) ** 2
    h = 2 * AVG_EARTH_RADIUS * np.arcsin(np.sqrt(d))*1000
    return h

# %%
# A little modification of this function by adding venue id
def getNearbyVenues2(latitude,longitude,radius=500):
            
    # create the API request URL
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET,  
        latitude, 
        longitude, 
        VERSION,
        search_query,
        radius, 
        LIMIT)

        # make the GET request
    results = requests.get(url).json()["response"]['venues']
        
    dataframe = json_normalize(results)
    # keep only columns that include venue name, and anything that is associated with location
    filtered_columns = ['name', 'categories'] +['location.lat','location.lng', 'location.address']+['id']#+['neighborhood']
    dataframe_filtered = dataframe.loc[:, filtered_columns]

    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

    dataframe_filtered=dataframe_filtered.rename(columns={"name": "Venue", "categories": "Venue category",'location.lat': 'Venue Latitide', 'location.lng':'Venue Longitude','location.address':'Address' })              
    return(dataframe_filtered)

# %% [markdown]
# ### Radius for search will be the half of distance between 2 endpoints

# %%
r=haversine_array(latitude,longitude,latitude2,longitude2)/2

# %% [markdown]
# #### Let's try to use with better function previous 2 locations

# %%
search_query = 'coffee'
#I decided to add extra 100m for distance
radius = r+100
dataframe_filtered_new= getNearbyVenues2(latitude,longitude,radius)
dataframe_filtered_new
# Out:
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          Venue Venue category  Venue Latitide  \
# 0  Hudson/Chambers Coffee Cart     Food Truck       40.715638
# 1    Laughing Man Coffee & Tea    Coffee Shop       40.717394
# 2      Jack’s Stir Brew Coffee    Coffee Shop       40.716450
# 3                  Coffee Cart    Coffee Shop       40.715331
# 4      MBJ Coffee Kiosk @ BMCC           Café       40.716990
# 5                 I m a coffee           Café       40.714289
# 6       38th floor coffee cart    Coffee Shop       40.714011
# 7                    Starbucks    Coffee Shop       40.715534
#
#    Venue Longitude                              Address  \
# 0       -74.009613                          Chambers St
# 1       -74.010103                         184 Duane St
# 2       -74.009755                         139 Reade St
# 3       -74.011562                                  NaN
# 4       -74.012021  199 Chambers St, New York, NY 10013
# 5       -74.010661                     9 Saint Marks Pl
# 6       -74.013645                         200 Vesey St
# 7       -74.009030                      125 Chambers St
#
#                          id
# 0  50a38463e4b0d1371722335f
# 1  4ea0afbf9adf1e334e4cc0e6
# 2  597a11ccb2958f056b27c60d
# 3  4e6ded5e45dd293273a36c79
# 4  4f7c472de4b09b8aeaed0826
# 5  52a3a47e11d2b5d5943d33dc
# 6  5214cdc411d2f67e0de859f4
# 7  4a718a5af964a52041d91fe3

# %%
search_query = 'coffee'
radius = r+100
dataframe_filtered2new= getNearbyVenues2(latitude2,longitude2,radius)
dataframe_filtered2new
# Out:
# /Users/Dariga/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                           Venue Venue category  Venue Latitide  \
# 0         Blue Spoon Coffee Co.    Coffee Shop       40.714428
# 1   Hudson/Chambers Coffee Cart     Food Truck       40.715638
# 2     Laughing Man Coffee & Tea    Coffee Shop       40.717394
# 3       Jack’s Stir Brew Coffee    Coffee Shop       40.716450
# 4                   Coffee Cart     Food Truck       40.717064
# 5                   Coffee Shop           Café       40.718039
# 6                  Sam's Coffee     Food Truck       40.716706
# 7                Supreme Coffee     Food Truck       40.716884
# 8          george howell coffee    Coffee Shop       40.718582
# 9       Mr. Akram's Coffee Cart     Food Truck       40.718953
# 10                    Starbucks    Coffee Shop       40.715534
# 11                    Starbucks    Coffee Shop       40.714855
#
#     Venue Longitude                       Address                        id
# 0        -74.006859                76 Chambers St  49c79540f964a520af571fe3
# 1        -74.009613                   Chambers St  50a38463e4b0d1371722335f
# 2        -74.010103                  184 Duane St  4ea0afbf9adf1e334e4cc0e6
# 3        -74.009755                  139 Reade St  597a11ccb2958f056b27c60d
# 4        -74.006391  W. Broadway  & Thomas Street  50781223e4b047ff2af4c231
# 5        -74.008331                           NaN  4e9d9fa06c251c381e0f68da
# 6        -74.006250                214 Church St.  4cab17e6f47ea14340588821
# 7        -74.005879                   60 Worth St  4bc710c68b7c9c7450b435cf
# 8        -74.005577               102 Franklin St  539212f3498e10da32c38e98
# 9        -74.006673                           NaN  4c97590f6b35a143141b35dc
# 10       -74.009030               125 Chambers St  4a718a5af964a52041d91fe3
# 11       -74.005936                  291 Broadway  4aea76b3f964a520abbb21e3

# %%
res=pd.concat([dataframe_filtered_new,dataframe_filtered2new],ignore_index=True)
duplicateRowsDF = res[res.duplicated(['Address'], keep='first')]
duplicateRowsDF=duplicateRowsDF.dropna(subset=['Address']).reset_index()
duplicateRowsDF
# Out:
#    index                        Venue Venue category  Venue Latitide  \
# 0      9  Hudson/Chambers Coffee Cart     Food Truck       40.715638
# 1     10    Laughing Man Coffee & Tea    Coffee Shop       40.717394
# 2     11      Jack’s Stir Brew Coffee    Coffee Shop       40.716450
# 3     18                    Starbucks    Coffee Shop       40.715534
#
#    Venue Longitude          Address                        id
# 0       -74.009613      Chambers St  50a38463e4b0d1371722335f
# 1       -74.010103     184 Duane St  4ea0afbf9adf1e334e4cc0e6
# 2       -74.009755     139 Reade St  597a11ccb2958f056b27c60d
# 3       -74.009030  125 Chambers St  4a718a5af964a52041d91fe3

# %% [markdown]
# We can see how number of common venues has dropped
#
# ### Visualization of common and equal distanced locations

# %%
venues_map = folium.Map(location=[latitude2, longitude2], zoom_start=13) 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Your location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

folium.features.CircleMarker(
    [latitude2, longitude2],
    radius=10,
    color='red',
    popup='Partners location',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(duplicateRowsDF['Venue Latitide'], duplicateRowsDF['Venue Longitude'], duplicateRowsDF['Venue category']):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Now it looks much better!

# %%
# Saving ids for getting their ratings
ids=duplicateRowsDF['id'].tolist()

# %%
# Function to get venues rating
def get_rating(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

    result = requests.get(url).json()
    try:
        return result['response']['venue']['rating']
    except:
        return(0)

# %%
score=[]
for vid in ids:
    score.append(get_rating(vid))
duplicateRowsDF['rating']=score

# %%
duplicateRowsDF.sort_values(['rating'], ascending = False)
# Out:
#    index                        Venue Venue category  Venue Latitide  \
# 1     10    Laughing Man Coffee & Tea    Coffee Shop       40.717394
# 2     11      Jack’s Stir Brew Coffee    Coffee Shop       40.716450
# 3     18                    Starbucks    Coffee Shop       40.715534
# 0      9  Hudson/Chambers Coffee Cart     Food Truck       40.715638
#
#    Venue Longitude          Address                        id  rating
# 1       -74.010103     184 Duane St  4ea0afbf9adf1e334e4cc0e6     8.8
# 2       -74.009755     139 Reade St  597a11ccb2958f056b27c60d     7.5
# 3       -74.009030  125 Chambers St  4a718a5af964a52041d91fe3     6.5
# 0       -74.009613      Chambers St  50a38463e4b0d1371722335f     0.0
